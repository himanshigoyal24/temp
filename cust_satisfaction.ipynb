# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('cust_satisfaction.csv')

# %%
df.drop_duplicates(inplace=True)

# %%
df.dropna(inplace=True)

# %%
print("total null values",df.isnull().sum())
print("total duplicate values",df.duplicated().sum())
# Out:
# total null values Gender                        0
# Customer Type                 0
# Type of Travel                0
# Class                         0
# satisfaction                  0
# Age                           0
# Flight Distance               0
# Inflight entertainment        0
# Baggage handling              0
# Cleanliness                   0
# Departure Delay in Minutes    0
# Arrival Delay in Minutes      0
# dtype: int64
# total duplicate values 0

# %%
df['Gender'] = df['Gender'].map({'Male':1, 'Female':0})
df['Customer Type'] = df['Customer Type'].map({'Loyal Customer':1, 'disloyal Customer':0})
df['Type of Travel'] = df['Type of Travel'].map({'Business travel':1, 'Personal Travel':0})
df['Class'] = df['Class'].map({'Business':2, 'Eco Plus':1, 'Eco':0})
df['satisfaction'] = df['satisfaction'].map({'satisfied':1, 'neutral or dissatisfied':0})

# %%
df
# Out:
#         Gender  Customer Type  Type of Travel  Class  satisfaction  Age  \
# 0            1              1               0      1             0   13
# 1            1              0               1      2             0   25
# 2            0              1               1      2             1   26
# 3            0              1               1      2             0   25
# 4            1              1               1      2             1   61
# ...        ...            ...             ...    ...           ...  ...
# 103899       0              0               1      0             0   23
# 103900       1              1               1      2             1   49
# 103901       1              0               1      2             0   30
# 103902       0              0               1      0             0   22
# 103903       1              1               1      2             0   27
#
#         Flight Distance  Inflight entertainment  Baggage handling  \
# 0                   460                       5                 4
# 1                   235                       1                 3
# 2                  1142                       5                 4
# 3                   562                       2                 3
# 4                   214                       3                 4
# ...                 ...                     ...               ...
# 103899              192                       2                 4
# 103900             2347                       5                 5
# 103901             1995                       4                 4
# 103902             1000                       1                 1
# 103903             1723                       1                 4
#
#         Cleanliness  Departure Delay in Minutes  Arrival Delay in Minutes
# 0                 5                          25                      18.0
# 1                 1                           1                       6.0
# 2                 5                           0                       0.0
# 3                 2                          11                       9.0
# 4                 3                           0                       0.0
# ...             ...                         ...                       ...
# 103899            2                           3                       0.0
# 103900            4                           0                       0.0
# 103901            4                           7                      14.0
# 103902            1                           0                       0.0
# 103903            1                           0                       0.0
#
# [103422 rows x 12 columns]

# %%
print("Total Index:",df['Customer Type'].value_counts().index)
# Out:
# Total Index: Index([1, 0], dtype='int64', name='Customer Type')

# %%
print("total values:",df['Customer Type'].value_counts().values)
# Out:
# total values: [84517 18905]

# %%
df['Customer Type'].value_counts().keys
# Out:
# <bound method Series.keys of Customer Type
# 1    84517
# 0    18905
# Name: count, dtype: int64>

# %%
indexing =list (df['Customer Type'].value_counts().keys())

# %%
values = list(df['Customer Type'].value_counts().values)

# %%
print("Indexing Value:-",df['Customer Type'].value_counts().index)
# Out:
# Indexing Value:- Index([1, 0], dtype='int64', name='Customer Type')

# %%
import pandas as pd

plot_df = pd.DataFrame({
    'Customer Type': indexing,
    'Count': values
})

sns.catplot(
    data=plot_df,
    x='Customer Type',
    y='Count',
    kind='bar',
    palette=['red', 'blue']
)
plt.xlabel('Customer Type')
# Out:
# C:\Users\shakeel\AppData\Local\Temp\ipykernel_16232\82509561.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(
# Text(0.5, 9.444444444444438, 'Customer Type')

# %%
loyal = df[df['Customer Type'] == 1].loc[0:20000]
disloyal = df[df['Customer Type'] == 0]

# %%
df=pd.concat([loyal,disloyal])

# %%
df
# Out:
#         Gender  Customer Type  Type of Travel  Class  satisfaction  Age  \
# 0            1              1               0      1             0   13
# 2            0              1               1      2             1   26
# 3            0              1               1      2             0   25
# 4            1              1               1      2             1   61
# 5            0              1               0      0             0   26
# ...        ...            ...             ...    ...           ...  ...
# 103892       0              0               1      2             0   37
# 103895       0              0               1      0             0   24
# 103899       0              0               1      0             0   23
# 103901       1              0               1      2             0   30
# 103902       0              0               1      0             0   22
#
#         Flight Distance  Inflight entertainment  Baggage handling  \
# 0                   460                       5                 4
# 2                  1142                       5                 4
# 3                   562                       2                 3
# 4                   214                       3                 4
# 5                  1180                       1                 4
# ...                 ...                     ...               ...
# 103892              596                       3                 3
# 103895             1055                       1                 5
# 103899              192                       2                 4
# 103901             1995                       4                 4
# 103902             1000                       1                 1
#
#         Cleanliness  Departure Delay in Minutes  Arrival Delay in Minutes
# 0                 5                          25                      18.0
# 2                 5                           0                       0.0
# 3                 2                          11                       9.0
# 4                 3                           0                       0.0
# 5                 1                           0                       0.0
# ...             ...                         ...                       ...
# 103892            3                         110                     121.0
# 103895            1                          13                      10.0
# 103899            2                           3                       0.0
# 103901            4                           7                      14.0
# 103902            1                           0                       0.0
#
# [35239 rows x 12 columns]

# %%
indexing =list (df['Customer Type'].value_counts().keys())
values = list(df['Customer Type'].value_counts().values)
sns.catplot(x=indexing, y=values, kind = 'bar', palette=['red','blue'])
# Out:
# C:\Users\shakeel\AppData\Local\Temp\ipykernel_16232\960633076.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(x=indexing, y=values, kind = 'bar', palette=['red','blue'])

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\shakeel\appdata\local\programs\python\python311\lib\site-packages (1.7.2)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\shakeel\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (2.3.3)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\shakeel\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (1.16.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\shakeel\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\shakeel\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.model_selection import train_test_split

# %%
x = df.drop('Type of Travel',axis=1)
y = df['Type of Travel']

# %%
x = df.drop('Gender',axis=1)
y = df['Gender']

# %%
x
# Out:
#         Customer Type  Type of Travel  Class  satisfaction  Age  \
# 0                   1               0      1             0   13
# 2                   1               1      2             1   26
# 3                   1               1      2             0   25
# 4                   1               1      2             1   61
# 5                   1               0      0             0   26
# ...               ...             ...    ...           ...  ...
# 103892              0               1      2             0   37
# 103895              0               1      0             0   24
# 103899              0               1      0             0   23
# 103901              0               1      2             0   30
# 103902              0               1      0             0   22
#
#         Flight Distance  Inflight entertainment  Baggage handling  \
# 0                   460                       5                 4
# 2                  1142                       5                 4
# 3                   562                       2                 3
# 4                   214                       3                 4
# 5                  1180                       1                 4
# ...                 ...                     ...               ...
# 103892              596                       3                 3
# 103895             1055                       1                 5
# 103899              192                       2                 4
# 103901             1995                       4                 4
# 103902             1000                       1                 1
#
#         Cleanliness  Departure Delay in Minutes  Arrival Delay in Minutes
# 0                 5                          25                      18.0
# 2                 5                           0                       0.0
# 3                 2                          11                       9.0
# 4                 3                           0                       0.0
# 5                 1                           0                       0.0
# ...             ...                         ...                       ...
# 103892            3                         110                     121.0
# 103895            1                          13                      10.0
# 103899            2                           3                       0.0
# 103901            4                           7                      14.0
# 103902            1                           0                       0.0
#
# [35239 rows x 11 columns]

# %%
y
# Out:
# 0         1
# 2         0
# 3         0
# 4         1
# 5         0
#          ..
# 103892    0
# 103895    0
# 103899    0
# 103901    1
# 103902    0
# Name: Gender, Length: 35239, dtype: int64

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y ,random_state=42, test_size=0.2)

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((28191, 11), (7048, 11), (28191,), (7048,))

# %%
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.models import Sequential
### Defining ANN Model

Ann_Model = Sequential()
# Hidden layers
Ann_Model.add(Dense(units=68,activation='relu', input_dim=x_train. shape[1]))
Ann_Model.add(Dense(units=32,activation='relu'))
Ann_Model.add(Dense(units=24,activation='relu' ))
Ann_Model.add(Dense(units=12,activation='relu'))
#output layers
Ann_Model.add(Dense(units=1,activation='sigmoid' ))

#compiling the models
Ann_Model. compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
Ann_Model. summary ()
# Out:
# c:\Users\shakeel\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\core\dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 68)             │           816 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,208 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 24)             │           792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 12)             │           300 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1)              │            13 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,129 (16.13 KB)
#  Trainable params: 4,129 (16.13 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = Ann_Model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=100, batch_size=64)
# Out:
# Epoch 1/100
# 441/441 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.5038 - loss: 1.2105 - val_accuracy: 0.5133 - val_loss: 0.7256
# Epoch 2/100
# 441/441 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5079 - loss: 0.8781 - val_accuracy: 0.4755 - val_loss: 0.8259
# Epoch 3/100
# 441/441 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5101 - loss: 0.7956 - val_accuracy: 0.4926 - val_loss: 0.7099
# Epoch 4/100
# 441/441 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.5057 - loss: 0.8245 - val_accuracy: 0.5236 - val_loss: 0.7136
# Epoch 5/100
# 441/441 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.5106 - loss: 0.8070 - val_accuracy: 0.5087 - val_loss: 0.7002
# Epoch 6/100
# 441/441 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5157 - loss: 0.7546 - val_accuracy: 0.5272 - val_loss: 0.8695
# Epoch 7/100
# 441/441 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5103 - loss: 0.7566 - val_accuracy: 0.4821 - val_loss: 0.8626
# Epoch 8/100
# 441/441 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5141 - loss: 0.7439 - val_accuracy: 0.4999 - val_loss: 0.7072
# Epoch 9/100
# 441/441 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5102 - loss: 0.7534 - val_accuracy: 0.5254 - val_loss: 0.7112
# Epoch 10/100
# 441/441 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.